# %% [markdown]
# # Threshold Validation Notebook
#
# This notebook provides a lightweight template for validating detection thresholds and visualising ROC/PR curves after running `train.py`. Populate it with real data by re-running the training pipeline to generate the necessary artifacts in `artifacts/`.

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics

ARTIFACTS = Path('artifacts')
THRESHOLDS_PATH = ARTIFACTS / 'metrics' / 'thresholds.json'
REPORT_PATH = ARTIFACTS / 'metrics' / 'report.json'

with THRESHOLDS_PATH.open() as f:
    thresholds = json.load(f)
with REPORT_PATH.open() as f:
    report = json.load(f)

thresholds, report
